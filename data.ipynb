# %%
import os
import xml.etree.ElementTree as ET

def xml_to_dict(element):
    """
    Recursively converts an XML element and its children into a dictionary,
    converting numerical strings to integers where applicable.
    """
    node_dict = {}
    
    # Include attributes if the element has any, converting any numeric strings to integers
    for attr, value in element.attrib.items():
        node_dict[attr] = int(value) if value.isdigit() else value
    
    # Iterate through children and add them to the dictionary
    for child in element:
        child_dict = xml_to_dict(child)
        # If tag already exists, make it a list
        if child.tag in node_dict:
            if not isinstance(node_dict[child.tag], list):
                node_dict[child.tag] = [node_dict[child.tag]]
            node_dict[child.tag].append(child_dict)
        else:
            node_dict[child.tag] = child_dict

    # Include the element text if it has text content, converting it to integer if possible
    if element.text and element.text.strip():
        text_content = element.text.strip()
        node_dict = int(text_content) if text_content.isdigit() else text_content

    return node_dict


def parse_xml_files_from_directory_to_dict(directory_path):
    data_dict = {}
    
    # List all files in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith('.xml'):
            file_path = os.path.join(directory_path, filename)
            
            try:
                # Parse the XML file
                tree = ET.parse(file_path)
                root = tree.getroot()
                
                # Convert XML content to dictionary
                data_dict[filename] = xml_to_dict(root)

            except ET.ParseError as e:
                print(f"Error parsing {filename}: {e}")
            except FileNotFoundError:
                print(f"File not found: {file_path}")
    
    return data_dict

# %%
from pathlib import Path


directory_path = Path('C:/Users/nicki/Downloads/atlas_dione_objectdetection.tar/atlas_dione_objectdetection/ATLAS_Dione_ObjectDetection/ATLAS_Dione_ObjectDetection.tar/ATLAS_Dione_ObjectDetection/Annotations')
xml_data_dict = parse_xml_files_from_directory_to_dict(directory_path)

# %%
xml_data_dict["set00V000I00000.xml"]
# Out:
# {'folder': 'VOCAtlas',
#  'filename': 'set00V000I00000',
#  'source': {'database': 'The VOCAtlas Database',
#   'annotation': 'PASCAL VOCAtlas',
#   'image': 'atlas',
#   'flickrid': 'n/a'},
#  'owner': {'flickrid': 'n/a', 'name': 'n/a'},
#  'size': {'width': 480, 'height': 854, 'depth': 3},
#  'segmented': 0,
#  'object': [{'name': 'tool',
#    'pose': 'Left',
#    'truncated': 0,
#    'occluded': 0,
#    'bndbox': {'xmin': 274, 'ymin': 189, 'xmax': 374, 'ymax': 244},
#    'difficult': 0},
#   {'name': 'tool',
#    'pose': 'Right',
#    'truncated': 0,
#    'occluded': 0,
#    'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 197},
#    'difficult': 0}]}

# %%
data = {}
for k,v in xml_data_dict.items():
    data[k] = {kk:vv for kk,vv in v.items() if kk in ["filename", "size", "object"]}
data
# Out:
# {'set00V000I00000.xml': {'filename': 'set00V000I00000',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 274, 'ymin': 189, 'xmax': 374, 'ymax': 244},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 197},
#     'difficult': 0}]},
#  'set00V000I00001.xml': {'filename': 'set00V000I00001',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 270, 'ymin': 189, 'xmax': 370, 'ymax': 244},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 194},
#     'difficult': 0}]},
#  'set00V000I00002.xml': {'filename': 'set00V000I00002',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 189, 'xmax': 370, 'ymax': 244},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 194},
#     'difficult': 0}]},
#  'set00V000I00003.xml': {'filename': 'set00V000I00003',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 189, 'xmax': 370, 'ymax': 238},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 194},
#     'difficult': 0}]},
#  'set00V000I00004.xml': {'filename': 'set00V000I00004',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 370, 'ymax': 244},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 194},
#     'difficult': 0}]},
#  'set00V000I00005.xml': {'filename': 'set00V000I00005',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 370, 'ymax': 244},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 194},
#     'difficult': 0}]},
#  'set00V000I00006.xml': {'filename': 'set00V000I00006',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 370, 'ymax': 244},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00007.xml': {'filename': 'set00V000I00007',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 371, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00008.xml': {'filename': 'set00V000I00008',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 371, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00009.xml': {'filename': 'set00V000I00009',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 372, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00010.xml': {'filename': 'set00V000I00010',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 269, 'ymin': 191, 'xmax': 372, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00011.xml': {'filename': 'set00V000I00011',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 372, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 196},
#     'difficult': 0}]},
#  'set00V000I00012.xml': {'filename': 'set00V000I00012',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 372, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 196},
#     'difficult': 0}]},
#  'set00V000I00013.xml': {'filename': 'set00V000I00013',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 373, 'ymax': 245},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 196},
#     'difficult': 0}]},
#  'set00V000I00014.xml': {'filename': 'set00V000I00014',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 374, 'ymax': 246},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00015.xml': {'filename': 'set00V000I00015',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 374, 'ymax': 246},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00016.xml': {'filename': 'set00V000I00016',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 374, 'ymax': 246},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00017.xml': {'filename': 'set00V000I00017',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 268, 'ymin': 191, 'xmax': 374, 'ymax': 246},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00018.xml': {'filename': 'set00V000I00018',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 274, 'ymin': 198, 'xmax': 380, 'ymax': 253},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00019.xml': {'filename': 'set00V000I00019',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 275, 'ymin': 199, 'xmax': 381, 'ymax': 254},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00020.xml': {'filename': 'set00V000I00020',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 275, 'ymin': 200, 'xmax': 380, 'ymax': 256},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00021.xml': {'filename': 'set00V000I00021',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 277, 'ymin': 199, 'xmax': 382, 'ymax': 255},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00022.xml': {'filename': 'set00V000I00022',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 200, 'xmax': 384, 'ymax': 259},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00023.xml': {'filename': 'set00V000I00023',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 279, 'ymin': 200, 'xmax': 385, 'ymax': 261},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00024.xml': {'filename': 'set00V000I00024',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 281, 'ymin': 201, 'xmax': 386, 'ymax': 263},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00025.xml': {'filename': 'set00V000I00025',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 283, 'ymin': 202, 'xmax': 388, 'ymax': 265},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00026.xml': {'filename': 'set00V000I00026',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 285, 'ymin': 203, 'xmax': 389, 'ymax': 266},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00027.xml': {'filename': 'set00V000I00027',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 287, 'ymin': 204, 'xmax': 389, 'ymax': 268},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00028.xml': {'filename': 'set00V000I00028',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 290, 'ymin': 204, 'xmax': 390, 'ymax': 268},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 121, 'xmax': 572, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00029.xml': {'filename': 'set00V000I00029',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 293, 'ymin': 205, 'xmax': 391, 'ymax': 270},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 462, 'ymin': 121, 'xmax': 573, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00030.xml': {'filename': 'set00V000I00030',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00031.xml': {'filename': 'set00V000I00031',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00032.xml': {'filename': 'set00V000I00032',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 195},
#     'difficult': 0}]},
#  'set00V000I00033.xml': {'filename': 'set00V000I00033',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 197},
#     'difficult': 0}]},
#  'set00V000I00034.xml': {'filename': 'set00V000I00034',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 198},
#     'difficult': 0}]},
#  'set00V000I00035.xml': {'filename': 'set00V000I00035',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 197},
#     'difficult': 0}]},
#  'set00V000I00036.xml': {'filename': 'set00V000I00036',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 206, 'xmax': 390, 'ymax': 274},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 121, 'xmax': 572, 'ymax': 197},
#     'difficult': 0}]},
#  'set00V000I00037.xml': {'filename': 'set00V000I00037',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 207, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 457, 'ymin': 122, 'xmax': 571, 'ymax': 201},
#     'difficult': 0}]},
#  'set00V000I00038.xml': {'filename': 'set00V000I00038',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 207, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 457, 'ymin': 122, 'xmax': 571, 'ymax': 199},
#     'difficult': 0}]},
#  'set00V000I00039.xml': {'filename': 'set00V000I00039',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 207, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 457, 'ymin': 123, 'xmax': 571, 'ymax': 200},
#     'difficult': 0}]},
#  'set00V000I00040.xml': {'filename': 'set00V000I00040',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 207, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 457, 'ymin': 126, 'xmax': 571, 'ymax': 203},
#     'difficult': 0}]},
#  'set00V000I00041.xml': {'filename': 'set00V000I00041',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 207, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 455, 'ymin': 126, 'xmax': 571, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V000I00042.xml': {'filename': 'set00V000I00042',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 455, 'ymin': 126, 'xmax': 571, 'ymax': 210},
#     'difficult': 0}]},
#  'set00V000I00043.xml': {'filename': 'set00V000I00043',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 456, 'ymin': 126, 'xmax': 571, 'ymax': 212},
#     'difficult': 0}]},
#  'set00V000I00044.xml': {'filename': 'set00V000I00044',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 126, 'xmax': 572, 'ymax': 213},
#     'difficult': 0}]},
#  'set00V000I00045.xml': {'filename': 'set00V000I00045',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 125, 'xmax': 572, 'ymax': 214},
#     'difficult': 0}]},
#  'set00V000I00046.xml': {'filename': 'set00V000I00046',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 125, 'xmax': 572, 'ymax': 214},
#     'difficult': 0}]},
#  'set00V000I00047.xml': {'filename': 'set00V000I00047',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 125, 'xmax': 572, 'ymax': 218},
#     'difficult': 0}]},
#  'set00V000I00048.xml': {'filename': 'set00V000I00048',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 126, 'xmax': 572, 'ymax': 220},
#     'difficult': 0}]},
#  'set00V000I00049.xml': {'filename': 'set00V000I00049',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 465, 'ymin': 127, 'xmax': 572, 'ymax': 222},
#     'difficult': 0}]},
#  'set00V000I00050.xml': {'filename': 'set00V000I00050',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 466, 'ymin': 128, 'xmax': 571, 'ymax': 223},
#     'difficult': 0}]},
#  'set00V000I00051.xml': {'filename': 'set00V000I00051',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 467, 'ymin': 130, 'xmax': 571, 'ymax': 230},
#     'difficult': 0}]},
#  'set00V000I00052.xml': {'filename': 'set00V000I00052',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 132, 'xmax': 573, 'ymax': 232},
#     'difficult': 0}]},
#  'set00V000I00053.xml': {'filename': 'set00V000I00053',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 137, 'xmax': 572, 'ymax': 240},
#     'difficult': 0}]},
#  'set00V000I00054.xml': {'filename': 'set00V000I00054',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 141, 'xmax': 571, 'ymax': 244},
#     'difficult': 0}]},
#  'set00V000I00055.xml': {'filename': 'set00V000I00055',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 145, 'xmax': 571, 'ymax': 248},
#     'difficult': 0}]},
#  'set00V000I00056.xml': {'filename': 'set00V000I00056',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 148, 'xmax': 570, 'ymax': 250},
#     'difficult': 0}]},
#  'set00V000I00057.xml': {'filename': 'set00V000I00057',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 472, 'ymin': 152, 'xmax': 569, 'ymax': 254},
#     'difficult': 0}]},
#  'set00V000I00058.xml': {'filename': 'set00V000I00058',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 472, 'ymin': 153, 'xmax': 569, 'ymax': 254},
#     'difficult': 0}]},
#  'set00V000I00059.xml': {'filename': 'set00V000I00059',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 471, 'ymin': 156, 'xmax': 568, 'ymax': 256},
#     'difficult': 0}]},
#  'set00V000I00060.xml': {'filename': 'set00V000I00060',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 295, 'ymin': 208, 'xmax': 390, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 161, 'xmax': 567, 'ymax': 260},
#     'difficult': 0}]},
#  'set00V000I00061.xml': {'filename': 'set00V000I00061',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 298, 'ymin': 208, 'xmax': 393, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 474, 'ymin': 163, 'xmax': 571, 'ymax': 269},
#     'difficult': 0}]},
#  'set00V000I00062.xml': {'filename': 'set00V000I00062',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 301, 'ymin': 208, 'xmax': 396, 'ymax': 275},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 167, 'xmax': 567, 'ymax': 273},
#     'difficult': 0}]},
#  'set00V000I00063.xml': {'filename': 'set00V000I00063',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 308, 'ymin': 212, 'xmax': 403, 'ymax': 279},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 468, 'ymin': 170, 'xmax': 565, 'ymax': 276},
#     'difficult': 0}]},
#  'set00V000I00064.xml': {'filename': 'set00V000I00064',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 312, 'ymin': 214, 'xmax': 407, 'ymax': 281},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 469, 'ymin': 175, 'xmax': 566, 'ymax': 281},
#     'difficult': 0}]},
#  'set00V000I00065.xml': {'filename': 'set00V000I00065',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 315, 'ymin': 216, 'xmax': 410, 'ymax': 283},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 469, 'ymin': 185, 'xmax': 566, 'ymax': 285},
#     'difficult': 0}]},
#  'set00V000I00066.xml': {'filename': 'set00V000I00066',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 318, 'ymin': 218, 'xmax': 413, 'ymax': 285},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 469, 'ymin': 185, 'xmax': 566, 'ymax': 284},
#     'difficult': 0}]},
#  'set00V000I00067.xml': {'filename': 'set00V000I00067',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 327, 'ymin': 221, 'xmax': 423, 'ymax': 290},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 470, 'ymin': 186, 'xmax': 567, 'ymax': 285},
#     'difficult': 0}]},
#  'set00V000I00068.xml': {'filename': 'set00V000I00068',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 330, 'ymin': 223, 'xmax': 426, 'ymax': 292},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 469, 'ymin': 186, 'xmax': 565, 'ymax': 285},
#     'difficult': 0}]},
#  'set00V000I00069.xml': {'filename': 'set00V000I00069',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 331, 'ymin': 224, 'xmax': 427, 'ymax': 293},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 466, 'ymin': 186, 'xmax': 562, 'ymax': 285},
#     'difficult': 0}]},
#  'set00V000I00070.xml': {'filename': 'set00V000I00070',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 332, 'ymin': 225, 'xmax': 428, 'ymax': 294},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 465, 'ymin': 186, 'xmax': 561, 'ymax': 285},
#     'difficult': 0}]},
#  'set00V000I00071.xml': {'filename': 'set00V000I00071',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 334, 'ymin': 226, 'xmax': 430, 'ymax': 295},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 464, 'ymin': 186, 'xmax': 560, 'ymax': 285},
#     'difficult': 0}]},
#  'set00V000I00072.xml': {'filename': 'set00V000I00072',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 335, 'ymin': 227, 'xmax': 431, 'ymax': 296},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 463, 'ymin': 183, 'xmax': 558, 'ymax': 282},
#     'difficult': 0}]},
#  'set00V000I00073.xml': {'filename': 'set00V000I00073',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 335, 'ymin': 228, 'xmax': 431, 'ymax': 298},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 462, 'ymin': 184, 'xmax': 557, 'ymax': 283},
#     'difficult': 0}]},
#  'set00V000I00074.xml': {'filename': 'set00V000I00074',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 336, 'ymin': 229, 'xmax': 432, 'ymax': 299},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 462, 'ymin': 185, 'xmax': 557, 'ymax': 284},
#     'difficult': 0}]},
#  'set00V000I00075.xml': {'filename': 'set00V000I00075',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 337, 'ymin': 230, 'xmax': 433, 'ymax': 300},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 187, 'xmax': 555, 'ymax': 286},
#     'difficult': 0}]},
#  'set00V000I00076.xml': {'filename': 'set00V000I00076',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 337, 'ymin': 231, 'xmax': 437, 'ymax': 303},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 461, 'ymin': 187, 'xmax': 555, 'ymax': 286},
#     'difficult': 0}]},
#  'set00V000I00077.xml': {'filename': 'set00V000I00077',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 337, 'ymin': 232, 'xmax': 437, 'ymax': 304},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 187, 'xmax': 555, 'ymax': 286},
#     'difficult': 0}]},
#  'set00V000I00078.xml': {'filename': 'set00V000I00078',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 338, 'ymin': 234, 'xmax': 438, 'ymax': 306},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 187, 'xmax': 555, 'ymax': 286},
#     'difficult': 0}]},
#  'set00V000I00079.xml': {'filename': 'set00V000I00079',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 346, 'ymin': 236, 'xmax': 439, 'ymax': 308},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 191, 'xmax': 557, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00080.xml': {'filename': 'set00V000I00080',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 351, 'ymin': 239, 'xmax': 442, 'ymax': 311},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 191, 'xmax': 557, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00081.xml': {'filename': 'set00V000I00081',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 354, 'ymin': 245, 'xmax': 447, 'ymax': 317},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 191, 'xmax': 557, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00082.xml': {'filename': 'set00V000I00082',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 358, 'ymin': 247, 'xmax': 450, 'ymax': 318},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 191, 'xmax': 557, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00083.xml': {'filename': 'set00V000I00083',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 361, 'ymin': 249, 'xmax': 453, 'ymax': 320},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 191, 'xmax': 555, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00084.xml': {'filename': 'set00V000I00084',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 361, 'ymin': 252, 'xmax': 455, 'ymax': 323},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 191, 'xmax': 554, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00085.xml': {'filename': 'set00V000I00085',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 363, 'ymin': 255, 'xmax': 457, 'ymax': 325},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 191, 'xmax': 554, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00086.xml': {'filename': 'set00V000I00086',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 365, 'ymin': 258, 'xmax': 459, 'ymax': 328},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 191, 'xmax': 554, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00087.xml': {'filename': 'set00V000I00087',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 368, 'ymin': 261, 'xmax': 463, 'ymax': 335},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 191, 'xmax': 553, 'ymax': 290},
#     'difficult': 0}]},
#  'set00V000I00088.xml': {'filename': 'set00V000I00088',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 372, 'ymin': 264, 'xmax': 467, 'ymax': 337},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 459, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00089.xml': {'filename': 'set00V000I00089',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 377, 'ymin': 267, 'xmax': 469, 'ymax': 338},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 459, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00090.xml': {'filename': 'set00V000I00090',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 383, 'ymin': 271, 'xmax': 466, 'ymax': 339},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00091.xml': {'filename': 'set00V000I00091',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 385, 'ymin': 269, 'xmax': 468, 'ymax': 337},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00092.xml': {'filename': 'set00V000I00092',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 386, 'ymin': 268, 'xmax': 469, 'ymax': 336},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00093.xml': {'filename': 'set00V000I00093',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 387, 'ymin': 268, 'xmax': 470, 'ymax': 336},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00094.xml': {'filename': 'set00V000I00094',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 388, 'ymin': 267, 'xmax': 471, 'ymax': 334},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 460, 'ymin': 190, 'xmax': 554, 'ymax': 289},
#     'difficult': 0}]},
#  'set00V000I00095.xml': {'filename': 'set00V000I00095',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 389, 'ymin': 266, 'xmax': 472, 'ymax': 333},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 194, 'xmax': 554, 'ymax': 293},
#     'difficult': 0}]},
#  'set00V000I00096.xml': {'filename': 'set00V000I00096',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 389, 'ymin': 265, 'xmax': 472, 'ymax': 330},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 194, 'xmax': 554, 'ymax': 293},
#     'difficult': 0}]},
#  'set00V000I00097.xml': {'filename': 'set00V000I00097',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 390, 'ymin': 262, 'xmax': 473, 'ymax': 326},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 194, 'xmax': 554, 'ymax': 293},
#     'difficult': 0}]},
#  'set00V000I00098.xml': {'filename': 'set00V000I00098',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 391, 'ymin': 260, 'xmax': 474, 'ymax': 324},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 458, 'ymin': 194, 'xmax': 553, 'ymax': 293},
#     'difficult': 0}]},
#  'set00V000I00099.xml': {'filename': 'set00V000I00099',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 392, 'ymin': 260, 'xmax': 475, 'ymax': 323},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 456, 'ymin': 193, 'xmax': 551, 'ymax': 292},
#     'difficult': 0}]},
#  'set00V000I00100.xml': {'filename': 'set00V000I00100',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 392, 'ymin': 259, 'xmax': 475, 'ymax': 322},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 456, 'ymin': 193, 'xmax': 551, 'ymax': 292},
#     'difficult': 0}]},
#  'set00V000I00101.xml': {'filename': 'set00V000I00101',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 393, 'ymin': 258, 'xmax': 476, 'ymax': 317},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 456, 'ymin': 193, 'xmax': 551, 'ymax': 292},
#     'difficult': 0}]},
#  'set00V000I00102.xml': {'filename': 'set00V000I00102',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 394, 'ymin': 258, 'xmax': 477, 'ymax': 317},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 456, 'ymin': 193, 'xmax': 551, 'ymax': 292},
#     'difficult': 0}]},
#  'set00V000I00103.xml': {'filename': 'set00V000I00103',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 395, 'ymin': 257, 'xmax': 478, 'ymax': 317},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 456, 'ymin': 193, 'xmax': 551, 'ymax': 292},
#     'difficult': 0}]},
#  'set00V000I00104.xml': {'filename': 'set00V000I00104',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 395, 'ymin': 257, 'xmax': 478, 'ymax': 317},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
# ...
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 581, 'ymin': 141, 'xmax': 672, 'ymax': 209},
#     'difficult': 0}]},
#  'set00V002I00092.xml': {'filename': 'set00V002I00092',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 143, 'xmax': 674, 'ymax': 211},
#     'difficult': 0}]},
#  'set00V002I00093.xml': {'filename': 'set00V002I00093',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 143, 'xmax': 674, 'ymax': 211},
#     'difficult': 0}]},
#  'set00V002I00094.xml': {'filename': 'set00V002I00094',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 143, 'xmax': 674, 'ymax': 211},
#     'difficult': 0}]},
#  'set00V002I00095.xml': {'filename': 'set00V002I00095',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 585, 'ymin': 146, 'xmax': 671, 'ymax': 209},
#     'difficult': 0}]},
#  'set00V002I00096.xml': {'filename': 'set00V002I00096',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 588, 'ymin': 144, 'xmax': 674, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00097.xml': {'filename': 'set00V002I00097',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 588, 'ymin': 144, 'xmax': 674, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00098.xml': {'filename': 'set00V002I00098',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 588, 'ymin': 143, 'xmax': 674, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00099.xml': {'filename': 'set00V002I00099',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 588, 'ymin': 143, 'xmax': 674, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00100.xml': {'filename': 'set00V002I00100',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 200, 'xmax': 371, 'ymax': 277},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 587, 'ymin': 143, 'xmax': 674, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00101.xml': {'filename': 'set00V002I00101',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 200, 'xmax': 371, 'ymax': 277},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 587, 'ymin': 143, 'xmax': 670, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00102.xml': {'filename': 'set00V002I00102',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 201, 'xmax': 371, 'ymax': 278},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 142, 'xmax': 666, 'ymax': 205},
#     'difficult': 0}]},
#  'set00V002I00103.xml': {'filename': 'set00V002I00103',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 201, 'xmax': 371, 'ymax': 278},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 142, 'xmax': 662, 'ymax': 205},
#     'difficult': 0}]},
#  'set00V002I00104.xml': {'filename': 'set00V002I00104',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 200, 'xmax': 371, 'ymax': 277},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 142, 'xmax': 660, 'ymax': 205},
#     'difficult': 0}]},
#  'set00V002I00105.xml': {'filename': 'set00V002I00105',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 142, 'xmax': 661, 'ymax': 205},
#     'difficult': 0}]},
#  'set00V002I00106.xml': {'filename': 'set00V002I00106',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00107.xml': {'filename': 'set00V002I00107',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00108.xml': {'filename': 'set00V002I00108',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00109.xml': {'filename': 'set00V002I00109',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00110.xml': {'filename': 'set00V002I00110',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00111.xml': {'filename': 'set00V002I00111',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00112.xml': {'filename': 'set00V002I00112',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 584, 'ymin': 145, 'xmax': 663, 'ymax': 208},
#     'difficult': 0}]},
#  'set00V002I00113.xml': {'filename': 'set00V002I00113',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 584, 'ymin': 145, 'xmax': 663, 'ymax': 208},
#     'difficult': 0}]},
#  'set00V002I00114.xml': {'filename': 'set00V002I00114',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 584, 'ymin': 145, 'xmax': 663, 'ymax': 208},
#     'difficult': 0}]},
#  'set00V002I00115.xml': {'filename': 'set00V002I00115',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 584, 'ymin': 145, 'xmax': 663, 'ymax': 208},
#     'difficult': 0}]},
#  'set00V002I00116.xml': {'filename': 'set00V002I00116',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 584, 'ymin': 145, 'xmax': 663, 'ymax': 208},
#     'difficult': 0}]},
#  'set00V002I00117.xml': {'filename': 'set00V002I00117',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 144, 'xmax': 662, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00118.xml': {'filename': 'set00V002I00118',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 144, 'xmax': 662, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00119.xml': {'filename': 'set00V002I00119',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 583, 'ymin': 144, 'xmax': 662, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00120.xml': {'filename': 'set00V002I00120',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 582, 'ymin': 143, 'xmax': 661, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00121.xml': {'filename': 'set00V002I00121',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 584, 'ymin': 143, 'xmax': 663, 'ymax': 206},
#     'difficult': 0}]},
#  'set00V002I00122.xml': {'filename': 'set00V002I00122',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 586, 'ymin': 144, 'xmax': 665, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00123.xml': {'filename': 'set00V002I00123',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 587, 'ymin': 144, 'xmax': 666, 'ymax': 207},
#     'difficult': 0}]},
#  'set00V002I00124.xml': {'filename': 'set00V002I00124',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 585, 'ymin': 144, 'xmax': 664, 'ymax': 208},
#     'difficult': 0}]},
#  'set00V002I00125.xml': {'filename': 'set00V002I00125',
#   'size': {'width': 480, 'height': 854, 'depth': 3},
#   'object': [{'name': 'tool',
#     'pose': 'Left',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 278, 'ymin': 199, 'xmax': 371, 'ymax': 276},
#     'difficult': 0},
#    {'name': 'tool',
#     'pose': 'Right',
#     'truncated': 0,
#     'occluded': 0,
#     'bndbox': {'xmin': 585, 'ymin': 144, 'xmax': 664, 'ymax': 208},
#     'difficult': 0}]},
#  ...}

# %%
import pickle

# Save to a pickle file
with open("data.pkl", "wb") as file:
    pickle.dump(data, file)

# %%
import os
import json
import xml.etree.ElementTree as ET
from typing import Dict, List, Any
from datetime import datetime

class XMLtoCOCO:
    def __init__(self):
        self.coco_format = {
            "info": {
                "year": datetime.now().year,
                "version": "1.0",
                "description": "Converted from XML",
                "contributor": "",
                "url": "",
                "date_created": datetime.now().strftime("%Y-%m-%d")
            },
            "licenses": [{
                "id": 1,
                "name": "Unknown",
                "url": ""
            }],
            "images": [],
            "annotations": [],
            "categories": []
        }
        self.category_id_map = {}
        self.annotation_id = 1

    def add_category(self, name: str) -> int:
        """Add a category if it doesn't exist and return its ID."""
        if name not in self.category_id_map:
            category_id = len(self.category_id_map) + 1
            self.category_id_map[name] = category_id
            self.coco_format["categories"].append({
                "id": category_id,
                "name": name,
                "supercategory": "none"
            })
        return self.category_id_map[name]

    def parse_xml(self, xml_path: str, image_id: int) -> Dict[str, Any]:
        """Parse a single XML file and return image and annotation data."""
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Get image information
        size = root.find('size')
        width = int(size.find('width').text)
        height = int(size.find('height').text)
        
        # Get filename
        filename = root.find('filename').text
        
        image_info = {
            "id": image_id,
            "file_name": filename + ".jpg",
            "width": width,
            "height": height,
            "license": 1,
            "date_captured": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        }

        annotations = []
        for obj in root.findall('object'):
            category_name = obj.find('pose').text +"_"+ obj.find('name').text
            category_id = self.add_category(category_name)
            
            bbox = obj.find('bndbox')
            xmin = float(bbox.find('xmin').text)
            ymin = float(bbox.find('ymin').text)
            xmax = float(bbox.find('xmax').text)
            ymax = float(bbox.find('ymax').text)
            
            # Calculate COCO format bbox [x,y,width,height]
            width = xmax - xmin
            height = ymax - ymin
            
            annotation = {
                "id": self.annotation_id,
                "image_id": image_id,
                "category_id": category_id,
                "bbox": [xmin, ymin, width, height],
                "area": width * height,
                "segmentation": [],  # Empty for bbox-only annotations
                "iscrowd": 0
            }
            
            annotations.append(annotation)
            self.annotation_id += 1

        return image_info, annotations

    def convert_directory(self, xml_dir: str, output_path: str) -> None:
        """Convert all XML files in a directory to COCO format."""
        image_id = 1
        
        # Process each XML file
        for xml_file in os.listdir(xml_dir):
            if xml_file.endswith('.xml'):
                xml_path = os.path.join(xml_dir, xml_file)
                image_info, annotations = self.parse_xml(xml_path, image_id)
                
                self.coco_format["images"].append(image_info)
                self.coco_format["annotations"].extend(annotations)
                
                image_id += 1

        # Save to JSON file
        with open(output_path, 'w') as f:
            json.dump(self.coco_format, f, indent=2)

    def convert_single_file(self, xml_path: str, output_path: str) -> None:
        """Convert a single XML file to COCO format."""
        image_info, annotations = self.parse_xml(xml_path, 1)
        
        self.coco_format["images"].append(image_info)
        self.coco_format["annotations"].extend(annotations)
        
        with open(output_path, 'w') as f:
            json.dump(self.coco_format, f, indent=2)

# %%
converter = XMLtoCOCO()
converter.convert_directory(directory_path, 'output.json')
